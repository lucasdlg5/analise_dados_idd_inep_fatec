# %% [markdown]
# <b><h1>Análise de dado do Inep - IDD</h1></b>

# %%
#Imports necessários para o projeto

# %matplotlib inline
import pandas as pd

# %%
filename = 'dataset/dataset_geral.csv'
df = pd.read_csv(filename, sep=";")

# %%
# Mostra as dez primeiras linhas do arquivo lido
df.head(10)
# Out:
#    nu_ano  co_grupo  co_ies  co_categad  co_orgacad  co_munic  co_uf_curso  \
# 0    2015         2       1       10002       10028   5103403          NaN
# 1    2015        13       1       10002       10028   5103403          NaN
# 2    2015        22       1       10002       10028   5103403          NaN
# 3    2015         1       1       10002       10028   5103403          NaN
# 4    2015        22       1       10002       10028   5107602          NaN
# 5    2015        13       2       10002       10028   5300108          NaN
# 6    2015        81       2       10002       10028   5300108          NaN
# 7    2015         1       2       10002       10028   5300108          NaN
# 8    2015         2       2       10002       10028   5300108          NaN
# 9    2015        22       2       10002       10028   5300108          NaN
#
#    co_regiao_curso  co_curso  ano_in_grad  ...  tp_pres  nt_ger  enem_nt_cn  \
# 0              NaN         1         2011  ...      555    74.8       662.6
# 1              NaN         2         2011  ...      555    36.2       533.4
# 2              NaN         8         2010  ...      555    46.4       654.2
# 3              NaN        13         2012  ...      555    44.3       500.9
# 4              NaN        21         2014  ...      555    39.2       438.5
# 5              NaN       122         2010  ...      555    36.2       775.3
# 6              NaN       128         2012  ...      555    65.3         707
# 7              NaN       145         2012  ...      555      74         578
# 8              NaN       148         2011  ...      555    68.6       677.5
# 9              NaN       149         2012  ...      555    45.2       599.5
#
#   enem_nt_ch enem_nt_lc enem_nt_mt co_modalidade IN_REGULAR  TP_INSCRICAO_ADM  \
# 0      708.2        672      866.4           1.0        NaN               NaN
# 1      657.2      573.7      636.2           1.0        NaN               NaN
# 2      562.7      615.9      686.6           1.0        NaN               NaN
# 3      510.2      510.3      508.6           1.0        NaN               NaN
# 4      424.8        506      529.7           1.0        NaN               NaN
# 5      775.8        752      828.3           1.0        NaN               NaN
# 6      727.5      663.1      814.3           1.0        NaN               NaN
# 7      663.5        630      636.7           1.0        NaN               NaN
# 8        766      677.5      837.5           1.0        NaN               NaN
# 9        566      637.6      870.8           1.0        NaN               NaN
#
#              ausente da lista 2015
# 0            auenste da lista 2014
# 1  Ausente da lista 2014,2015,2016
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
# [10 rows x 22 columns]

# %%
#Mostra quantidade de linhas e colunas

df.shape
# Out:
# (795751, 22)
